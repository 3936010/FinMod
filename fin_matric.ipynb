# %%
import sys
import os
import pandas as pd
import warnings
import json
from pydantic import BaseModel

# Add the src folder to the path
sys.path.append(os.path.abspath('../..'))
warnings.filterwarnings("ignore", category=FutureWarning)

# Import the classes
from utils.connect_db import ConnectDB
from utils.get_data import calculate_financial_metrics
from utils.connect_wrds import get_fundamentals_quarterly, get_security_daily

from llm.api_call import call_llm
from langchain_core.prompts import ChatPromptTemplate

db = ConnectDB()
engine = db.get_engine()

ticker = 'NVDA'
date = '2025-04-02'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 14
#      12 # Import the classes
#      13 from utils.connect_db import ConnectDB
# ---> 14 from utils.get_data import calculate_financial_metrics
#      15 from utils.connect_wrds import get_fundamentals_quarterly, get_security_daily
#      17 from llm.api_call import call_llm
#
# File ~/FinMod/utils/get_data.py:12
#      10 from utils.connect_wrds import get_fundamentals_quarterly, get_security_daily
#      11 from utils.data_models import FinancialMetrics, FinancialMetricsResponse, RetailActivityResponse, RetailActivity
# ---> 12 from utils.polygon_utils import polygon
#      14 logger = logging.getLogger(__name__)
#      16 def market_is_open(date):
#
# File ~/FinMod/utils/polygon_utils.py:9
#       7 from requests.exceptions import HTTPError
# ...
